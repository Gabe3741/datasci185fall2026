# %% [markdown]
# <font size = "30" color = "RED">
# This is my first Jupyter notebook

# %%
print("hello world")
print("My name is Gabe or Gabriel Hall")
# Out:
# hello world
# My name is Gabe or Gabriel Hall
